# %%
# 1. Positive Number

# Take a number from the user and check whether it is positive

import random
num=random.randint(1,100)
print(f"enter a number:{num}")
if num>0:
    print("positive number")
elif num==0:
    print("Zero")
else:
    print("Negative number")
# Out:
# enter a number:23
# positive number

# %%
# 2. Greater than 100
# Take a number as input and check whether it is greater than 100.

num=eval(input("enter a number : "))
if num>100:
    print("greater then 100 ")
else:
    print("less than 100")
# Out:
# less than 100

# %%
# 3. Voting Eligibility

# Take the user's age as input and check whether they are eligible to vote (18 or above).
num=int(input("enter a number:"))
if num>=18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# eligible for vote

# %%
# 4. Even or Odd
# Take a number from the user and print whether it is even or odd

import random
num=random.randint(1,100)
print(f"random number is:{num}")
if num%2==0:
    print(f"even number:{num}")
else:
    print(f"odd number:{num}")
# Out:
# random number is:12
# even number:12

# %%
# 5. Pass or Fail

# Take a student's marks as input and print:

# Pass if marks are 35 or above
# Fail otherwise

import random 
marks=random.randint(1,100)
print(f"enter marks:{marks}")
if marks>=35:
    print("Pass")
else:
    print("Fail")
# Out:
# enter marks:23
# Fail

# %%
# 6. Largest of Two Numbers

# Take two numbers as input and print the largest number.

n1=eval(input("enter a number 1:"))
n2=eval(input("enter a number 2:"))

if n1>n2:
    print("largest number is:",n1)
elif n2>n1:
    print("largest number is:",n2)
else:
    print("largest number is:",n3)
# Out:
# largest number is: 20

# %%
# 7. Grade Calculator
# Take marks as input and display the grade:
# 90–100 → Grade A
# 75–89 → Grade B
# 60–74 → Grade C
# 35–59 → Grade D
# Below 35 → Fail

marks=eval(input("Enter a marks:"))
if 90<marks<100:
    print("Grade A")
elif 75<marks<89:
    print("Grade B")
elif 60<marks<74:
    print("Grade C")
elif 35<marks<59:
    print("Grade D")
else:
    print("Fail")
# Out:
# Fail

# %%
# 8. Weekday Finder

# Take a number (1–7) as input and print:

# 1 → Monday
# 2 → Tuesday
# 3 → Wednesday
# 4 → Thursday
# 5 → Friday
# 6 → Saturday
# 7 → Sunday

# If the number is not between 1 and 7, print Invalid Day.

num=eval(input("enter a number (1-7):"))
if num==1:
    print("Monday")
elif num==2:
    print("Tuesday")
elif num==3:
    print("wednesday")
elif num==4:
    print("Tuesday")
elif num==5:
    print("Thursday")
elif num==6:
    print("Friday")
elif num==7:
    print("Sunday")
else:
    print("invalid Day!")
# Out:
# wednesday

# %%
# 9. Salary Bonus

# Take an employee's salary as input.

# Salary greater than ₹50,000 → Bonus = ₹10,000
# Salary between ₹30,000 and ₹50,000 → Bonus = ₹5,000
# Salary below ₹30,000 → No Bonus

# Print the bonus.

salary=float(input("Enter a salary:"))
if salary>50000:
    print("Bonus 10000")
elif 30000<salary<50000:
    print("Bonus 5000")
else:
    print(f"No Bonus")
# Out:
# No Bonus

# %%
# 10. Temperature Checker

# Take temperature as input.

# Above 35°C → Hot
# 20°C–35°C → Normal
# Below 20°C → Cold

temp=float(input("Enter a temperature:"))
if temp>35:
    print("Hot")
elif 20<temp<35:
    print("Normal")
else:
    print("Cold")
# Out:
# Hot

# %%
# 11. Login System

# Take:

# Username
# Password

# If the username is "admin" and the password is "1234", print Login Successful; otherwise print Invalid Username or Password.

user_name=eval(input("Enter a user name:"))
password=int(input("Enter a password:"))

if user_name=="admin" and password==1234:
    print("Login Successful!")
elif  user_name=="ramya":
    print("invalid Username!")
elif password==1324:
    print("invalid password!")
else:
    print("plase Enter correctly!")
# Out:
# plase Enter correctly!

# %%
# 12. ATM Withdrawal

# Take:

# Account Balance
# Withdrawal Amount

# If the withdrawal amount is less than or equal to the balance, print Transaction Successful; otherwise print Insufficient Balance.

account_balance=float(input("enter a account balance:"))
withdrawal_amount=int(input("enter a withdrawal amount:"))
if withdrawal_amount<=account_balance:
    print("Transaction Successful!")
else:
    print("Insufficient Balance.")
# Out:
# Transaction Successful!

# %%
# 13. College Admission

# Take:

# Marks
# Age

# Admission is allowed only if:

# Marks are 75 or above
# Age is 17 or above

# Otherwise, print Not Eligible for Admission.

marks=int(input("enter a marks:"))
age=int(input("enter a age:"))
print("\nAdmissions Opend")
print("="*20)
if marks>=75 and age>= 17:
    print("Eligible for Admission!")
else:
    print("Not Eligible for Admission!")
# Out:
# Admissions Opend
# ...
# Not Eligible for Admission!

# %%
# 14. Movie Ticket Eligibility

# Take:

# Age

# Print:

# Age below 5 → Free Ticket
# Age 5–17 → Child Ticket
# Age 18–59 → Adult Ticket
# Age 60 and above → Senior Citizen Ticket

age=int(input("enter a age:"))
if age<5:
    print("Free Ticket")
elif 5<age<59:
    print("child Ticket")
elif 18<age<59:
    print("Adult Ticket")
else:
    print("Senior Citizen Ticket")
# Out:
# child Ticket

# %%
# 15. Online Shopping Discount

# Take the purchase amount as input.

# Apply the following discount:

# ₹10,000 or more → 20% Discount
# ₹5,000–₹9,999 → 10% Discount
# ₹2,000–₹4,999 → 5% Discount
# Less than ₹2,000 → No Discount

# Print the discount percentage.

amount=eval(input("enter a purchsed amount:"))
if amount>=10000:
    print("20% Discount")
elif amount>=5000:
    print("10% Discount")
elif amount>=2000:
    print("5% Discount")
else:
    print("No Discount")
# Out:
# 20% Discount

# %%
# Write a program that asks the user to enter a length in centimetres. If the user enters
# a negative length, the program should tell the user that the entry is invalid. Otherwise,
# the program should convert the length to inches and print out the result. There are
# 2.54 centimetres in an inch. 1cm =0.39370079inches

length=float(input("enter  a length in centimeters:"))
if length<0:
    print("the entry is invalid!")
else:
    inches_in_centimeters=2.54
    length_in_inches=length/inches_in_centimeters
    print(f"length in inchese:{length_in_inches}")
# Out:
# length in inchese:13.779527559055119

# %%
# #### Problem-2(Use conditional statements)
# Ask the user for a temperature. Then ask them what units, Celsius or Fahrenheit, the
# temperature is in. Your program should convert the temperature to the other unit. The
# conversions are    F = (9/5 × C) + 32 and C = 5/9 × (F − 32)

temperature=float(input("enter a temperature:"))
units=input("enter units (Celsius or Fahrenheit):")
temperature_in_Fahrenheit=(9/5 * temperature) + 32
temperature_in_celsius=(5/9) * (temperature - 32)

if units=="Celsius":
    print(f"temperature in fahrenheit{temperature_in_Fahrenheit}")
elif units=="Fahrenheit":
    print(f"temperature in celsius {temperature_in_celsius}")

# %%
# Ask the user to enter a temperature in Celsius. The program should print a
# message based on the temperature:
# • If the temperature is less than -273.15, print that the temperature is invalid because it is
# below absolute zero.
# • If it is exactly -273.15, print that the temperature is absolute 0.
# • If the temperature is between -273.15 and 0, print that the temperature is below
# freezing. • If it is 0, print that the temperature is at the freezing point.
# • If it is between 0 and 100, print that the temperature is in the normal
# range. • If it is 100, print that the temperature is at the boiling point.
# • If it is above 100, print that the temperature is above the boiling point.
temp=float(input("enter a temperature in celsius:"))
if temp<-273.15:
    print("the temperature is invalid because it is below absolute zero.")
elif -273.15==0:
    print("the temperature is absolute 0.")
elif -273.15<temp< 0:
    print("the temperature is below freezing")
elif temp==0:
    print("the temperature is at the freezing point")
elif 0<temp<100:
    print("the temperature is in the normal range")
elif temp==100:
    print("the temperature is at the boiling point.")
else:
    print("the temperature is above the boiling point:")
# Out:
# the temperature is in the normal range

# %%
# Write a program that asks the user how many credits they have taken. If they have taken 23 or
# less, print that the student is a freshman. If they have taken between 24 and 53, print that they
# are asophomore. The range for juniors is 54 to 83, and for seniors it is 84 and over.

credits=int(input('enter a credits:'))

if credits <=23:
    print('the student is a freshman')
elif 24<=credits<=53:
    print('the student is a asophomore')
elif 54<=credits<=83:
    print('the student is a juniors')
else:
    print(f'the student is a senior {84}')
# Out:
# the student is a freshman

# %%
# A store charges $12 per item if you buy less than 10 items. If you buy between 10
# and 99 items, the cost is $10 per item. If you buy 100 or more items, the cost is $7
# per item. Write a program that asks the user how many items they are buying and
# prints the total cost.

items=int(input('enter number of items you are buying :'))
cost=int(input('enter a cost:'))
total_cost=items*cost
print(f'total cost is {total_cost}')
    
if items<10:
    print(f'the store charges $12 per item {10}')

elif 10<=items<=99:
    print(f'the cost is $10 per item {99}')

else:
    cost=7
    print(f'the cost is $7 per item {100}')
# Out:
# total cost is 2000000
# the cost is $7 per item 100
