# %% [markdown]
# ### What is an Operator?
# - Definition
#
#  - An operator is a symbol that performs an operation on one or more values (operands).
#
# - Simple Definition
#
#   - An operator is a symbol used to perform operations like addition, subtraction, comparison, and logical operations on variables or values.

# %%
a=10
b=5
print(f"Addition:{a+b}")


# Here:
# + - is an operator
# a and b are operands
# Out:
# Addition:15

# %% [markdown]
# #### Types of Operators in Python
# - 1.Arithmetic Operators
# - 2.Assignment Operators
# - 3.Comparison (Relational) Operators
# - 4.Logical Operators
# - 5.Bitwise Operators
# - 6.Membership Operators
# - 7.Identity Operators

# %% [markdown]
# ### 1. Arithmetic Operators
#
# - These operators perform mathematical calculations.

# %% [markdown]
# | Operator | Meaning             | Example        |
# | -------- | ------------------- | -------------- |
# | +        | Addition            | `10 + 5 = 15`  |
# | -        | Subtraction         | `10 - 5 = 5`   |
# | *        | Multiplication      | `10 * 5 = 50`  |
# | /        | Division            | `10 / 5 = 2.0` |
# | //       | Floor Division      | `10 // 3 = 3`  |
# | %        | Modulus (Remainder) | `10 % 3 = 1`   |
# | **       | Exponent (Power)    | `2 ** 3 = 8`   |

# %%
a=10
b=5
print(f"Addition      :{a+b}")
print(f"subtraction   :{a-b}")
print(f"multiplication:{a*b}")
print(f"Division      :{a/b}")
print(f"Floor Division:{a//b}")
print(f"Modulus       :{a%b}")
print(f"Exponent      :{a**b}")
# Out:
# Addition      :15
# subtraction   :5
# multiplication:50
# Division      :2.0
# Floor Division:2
# Modulus       :0
# Exponent      :100000

# %% [markdown]
# ### 2. Assignment Operators
#
# - Assignment operators assign values to variables.

# %% [markdown]
# | Operator | Example   | Same As      |
# | -------- | --------- | ------------ |
# | =        | `x = 10`  | Assign value |
# | +=       | `x += 5`  | `x = x + 5`  |
# | -=       | `x -= 5`  | `x = x - 5`  |
# | *=       | `x *= 5`  | `x = x * 5`  |
# | /=       | `x /= 5`  | `x = x / 5`  |
# | //=      | `x //= 5` | `x = x // 5` |
# | %=       | `x %= 5`  | `x = x % 5`  |
# | **=      | `x **= 2` | `x = x ** 2` |

# %%
x=10

x+=5
print(x)

x*=2
print(x)
# Out:
# 15
# 30

# %% [markdown]
# ### 3. Comparison (Relational) Operators
# - These operators compare two values and return True or False.

# %% [markdown]
# | Operator | Meaning                  |
# | -------- | ------------------------ |
# | ==       | Equal to                 |
# | !=       | Not Equal to             |
# | >        | Greater Than             |
# | <        | Less Than                |
# | >=       | Greater Than or Equal To |
# | <=       | Less Than or Equal To    |

# %%
a=10
b=20

print(f"Equal to                :{a==b}")
print(f"Not Equal to            :{a!=b}")
print(f"Greater Than            :{a>b}")
print(f"Less Than               :{a<b}")
print(f"Greater Than or Equal To:{a>=b}")
print(f"Less Than or Equal To   :{a<=b}")
# Out:
# Equal to                :False
# Not Equal to            :True
# Greater Than            :False
# Less Than               :True
# Greater Than or Equal To:False
# Less Than or Equal To   :True

# %% [markdown]
# ### 4. Logical Operators
#
# - Logical operators combine two or more conditions.

# %% [markdown]
# | Operator | Meaning                                |
# | -------- | -------------------------------------- |
# | and      | True if both conditions are True       |
# | or       | True if at least one condition is True |
# | not      | Reverses the result                    |

# %%
a=10
b=20

print(a<b and b>10)  # both conditions true
print(a>b or b>10)  # True if at least one condition is True
print(not(a<b))    # Reverses the result
# Out:
# True
# True
# False

# %% [markdown]
# #### Truth Table

# %% [markdown]
# #### 1.AND

# %% [markdown]
# | A     | B     | A and B |
# | ----- | ----- | ------- |
# | True  | True  | True    |
# | True  | False | False   |
# | False | True  | False   |
# | False | False | False   |

# %% [markdown]
# #### 2.OR

# %% [markdown]
# | A     | B     | A or B |
# | ----- | ----- | ------ |
# | True  | True  | True   |
# | True  | False | True   |
# | False | True  | True   |
# | False | False | False  |

# %% [markdown]
# #### 3.NOT

# %% [markdown]
# | A     | B     | A or B |
# | ----- | ----- | ------ |
# | True  | True  | True   |
# | True  | False | True   |
# | False | True  | True   |
# | False | False | False  |

# %% [markdown]
# ### 5 Bitwise Operators
#
# - Bitwise operators work on the binary (0s and 1s) representation of numbers.

# %% [markdown]
# | Operator | Meaning     |
# | -------- | ----------- |
# | &        | Bitwise AND |
# | |        | Bitwise OR  |
# | ^        | Bitwise XOR |
# | ~        | Bitwise NOT |
# | <<       | Left Shift  |
# | >>       | Right Shift |

# %%
a=5
b=3

print(f"Bitwise AND:{a&b}")
print(f"Bitwise XOR:{a|b}")
print(f"Bitwise NOT:{a^b}")
print(f"Left Shift :{a<<b}")
print(f"Right Shift:{a>>b}")
# Out:
# Bitwise AND:1
# Bitwise XOR:7
# Bitwise NOT:6
# Left Shift :40
# Right Shift:0

# %% [markdown]
# **Note**: Bitwise operators are generally used in system programming, embedded systems, and performance-critical applications.

# %% [markdown]
# ### 6. Membership Operators
#
# - Membership operators check whether a value exists in a sequence such as a string, list, tuple, set, or dictionary.

# %% [markdown]
# | Operator | Meaning              |
# | -------- | -------------------- |
# | in       | Value exists         |
# | not in   | Value does not exist |

# %%
fruits=["apple","banana","mango"]
print("apple" in fruits)
print("banana" in fruits)
print("mango" in fruits)
print("gua" in fruits)
# Out:
# True
# True
# True
# False

# %% [markdown]
# ### 7. Identity Operators
# - Identity operators compare whether two variables refer to the **same object in memory**.

# %% [markdown]
# | Operator | Meaning           |
# | -------- | ----------------- |
# | is       | Same object       |
# | is not   | Different objects |

# %%
a=[1,2,3]
b=a
c=[1,2,3]

print(a is b)
print(a is c)
print(a is not c)
# Out:
# True
# False
# True

# %% [markdown]
# #### Difference Between "==" and "is"

# %% [markdown]
# | `==`                       | `is`                                              |
# | -------------------------- | ------------------------------------------------- |
# | Compares values            | Compares memory identity (same object)            |
# | Checks if values are equal | Checks if both variables refer to the same object |

# %%
a=[1,2]
b=[1,2]

print(a==b)
print(a is b)
# Out:
# True
# False

# %% [markdown]
# #### Summary Table

# %% [markdown]
# | Operator Type | Purpose                                              |
# | ------------- | ---------------------------------------------------- |
# | Arithmetic    | Mathematical calculations                            |
# | Assignment    | Assign/update variable values                        |
# | Comparison    | Compare two values                                   |
# | Logical       | Combine conditions                                   |
# | Bitwise       | Binary operations                                    |
# | Membership    | Check if an item exists in a collection              |
# | Identity      | Check whether two variables refer to the same object |
