# %%
# WAP take three numbers find the average

# WAP calculate area of circle when radius given as 20
# assume pi=3.14
# Formula = pi*r*r

# WAP calculate area of right angle traingle when
# height given as 20, breadth given as 50
# Formual= 1/2*breadth*height

# Wap Calculate area of rectangle
# Formualr= length*breadth

# Wap calculate the weight in kgs when weight in pounds
# one pound= 2.2kgs

# Wap calculate the money in rupees when money in dollars
# one dollar= 90rs

# Wap ask the user calculate tax amount for a given salary 100000 and tax percenatge is 10

# %%
# WAP take three numbers find the average
a=5
b=2
c=3
avg=(a+b+c)/3
avg
# Out:
# 3.3333333333333335

# %%
# WAP calculate area of circle when radius given as 20
# assume pi=3.14  
# Formula = pi*r*r

radius=20
pi=3.14
area_of_circle=pi*radius*radius
area_of_circle
# Out:
# 1256.0

# %%
# WAP calculate area of right angle traingle when
# height given as 20, breadth given as 50
# Formual= 1/2*breadth*height

height=20
breadth=50
area_of_right_angle_triangle=1/2*height*breadth
area_of_right_angle_triangle
# Out:
# 500.0

# %%
# Wap Calculate area of rectangle
# Formualr= length*breadth

length=100
breadth=200
area_of_rectangle=length*breadth
area_of_rectangle
# Out:
# 20000

# %%
# Wap calculate the weight in kgs when weight in pounds
# one pound= 2.2kgs

weight_in_pond=100
one_pond_in_kgs=2.2
weight_in_kgs=weight_in_pond/one_pond_in_kgs
weight_in_kgs
# Out:
# 45.45454545454545

# %%
# Wap calculate the money in rupees when money in dollars
# one dollar= 90rs

money_in_dollars=100
one_dollar_in_money=90
money_in_rupees=money_in_dollars*one_dollar_in_money
money_in_rupees
# Out:
# 9000

# %%
# Wap ask the user calculate tax amount for a given salary 100000 and tax percenatge is 10

tax_percentage=10
given_salary=100000
tax_amount=tax_percentage*given_salary/100
tax_amount
# Out:
# 10000.0
